# %% [markdown]
# # Image Splitting by Lines
# Notebook for splitting images by line in a `directory` .

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def thresholding(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(img_gray,80,255,cv2.THRESH_BINARY_INV)
    return thresh

# %% [markdown]
# ## List files

# %%
import os

directory_path = 'synthetic_1'
all_entries = os.listdir(directory_path)
image_files = [os.path.join(directory_path, entry) for entry in all_entries if os.path.isfile(os.path.join(directory_path, entry)) and entry.lower().endswith(('.png', '.jpg', '.jpeg'))]

print(image_files)
# Out:
# ['synthetic_1/ilovepdf_merged-2-20_page-0017.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0014.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0006.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0008.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0018.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0005.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0015.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0003.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0016.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0007.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0002.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0004.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0019.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0011.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0013.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0012.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0001.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0010.jpg', 'synthetic_1/ilovepdf_merged-2-20_page-0009.jpg']

# %% [markdown]
# ## Iterate and process
#
# Loops through each image file, applies the existing preprocessing and line segmentation steps, then saves the bounded box image.

# %%
import shutil
from google.colab import files
import os
import cv2
import numpy as np

base_output_dir = 'segmented_lines_per_image'
os.makedirs(base_output_dir, exist_ok=True)

for image_file in image_files:
    print(f"Processing image: {image_file}")

    # Extract the original filename without extension
    original_filename = os.path.splitext(os.path.basename(image_file))[0]

    # Create a subdirectory for the current image
    image_output_dir = os.path.join(base_output_dir, original_filename)
    os.makedirs(image_output_dir, exist_ok=True)

    # Read each image and convert to RGB
    img = cv2.imread(image_file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Resize the image if its width is greater than 1000 pixels
    h, w, c = img.shape
    if w > 1000:
        new_w = 1000
        ar = w / h
        new_h = int(new_w / ar)
        img = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_AREA)

    # Apply thresholding
    thresh_img = thresholding(img)

    # Dilation for line segmentation
    kernel_line = np.ones((3, 85), np.uint8)
    dilated_line = cv2.dilate(thresh_img, kernel_line, iterations=1)

    # Find contours for line segmentation and sort
    (contours_line, heirarchy_line) = cv2.findContours(dilated_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    sorted_contours_lines = sorted(contours_line, key=lambda ctr: cv2.boundingRect(ctr)[1])

    # Save the segmented lines
    skipped_count = 0
    saved_count = 0
    for i, ctr in enumerate(sorted_contours_lines):
        # Get bounding box coordinates
        x, y, w, h = cv2.boundingRect(ctr)

        # Garbage images filter: check if the height is less than 25 pixels, if true; skip saving
        if h < 25:
            skipped_count += 1
            continue

        # Crop the image using the bounding box
        cropped_line = img[y:y+h, x:x+w]

        # Define the output filename
        output_filename = os.path.join(image_output_dir, f'line_{saved_count}.png')

        # Save the cropped line image
        cv2.imwrite(output_filename, cv2.cvtColor(cropped_line, cv2.COLOR_RGB2BGR))
        saved_count += 1

    print(f"Saved {saved_count} segmented lines for {original_filename} to '{image_output_dir}' directory.")
    print(f"Skipped {skipped_count} lines with height less than 25 pixels for {original_filename}.")


print("Finished processing all images.")
# Out:
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0017.jpg
# Saved 9 segmented lines for ilovepdf_merged-2-20_page-0017 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0017' directory.
# Skipped 23 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0017.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0014.jpg
# Saved 6 segmented lines for ilovepdf_merged-2-20_page-0014 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0014' directory.
# Skipped 1 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0014.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0006.jpg
# Saved 6 segmented lines for ilovepdf_merged-2-20_page-0006 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0006' directory.
# Skipped 5 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0006.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0008.jpg
# Saved 7 segmented lines for ilovepdf_merged-2-20_page-0008 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0008' directory.
# Skipped 5 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0008.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0018.jpg
# Saved 7 segmented lines for ilovepdf_merged-2-20_page-0018 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0018' directory.
# Skipped 0 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0018.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0005.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0005 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0005' directory.
# Skipped 3 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0005.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0015.jpg
# Saved 6 segmented lines for ilovepdf_merged-2-20_page-0015 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0015' directory.
# Skipped 6 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0015.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0003.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0003 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0003' directory.
# Skipped 2 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0003.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0016.jpg
# Saved 7 segmented lines for ilovepdf_merged-2-20_page-0016 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0016' directory.
# Skipped 5 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0016.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0007.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0007 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0007' directory.
# Skipped 2 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0007.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0002.jpg
# Saved 6 segmented lines for ilovepdf_merged-2-20_page-0002 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0002' directory.
# Skipped 3 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0002.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0004.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0004 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0004' directory.
# Skipped 3 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0004.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0019.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0019 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0019' directory.
# Skipped 2 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0019.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0011.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0011 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0011' directory.
# Skipped 3 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0011.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0013.jpg
# Saved 8 segmented lines for ilovepdf_merged-2-20_page-0013 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0013' directory.
# Skipped 14 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0013.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0012.jpg
# Saved 7 segmented lines for ilovepdf_merged-2-20_page-0012 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0012' directory.
# Skipped 1 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0012.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0001.jpg
# Saved 5 segmented lines for ilovepdf_merged-2-20_page-0001 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0001' directory.
# Skipped 2 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0001.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0010.jpg
# Saved 7 segmented lines for ilovepdf_merged-2-20_page-0010 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0010' directory.
# Skipped 5 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0010.
# Processing image: synthetic_1/ilovepdf_merged-2-20_page-0009.jpg
# Saved 6 segmented lines for ilovepdf_merged-2-20_page-0009 to 'segmented_lines_per_image/ilovepdf_merged-2-20_page-0009' directory.
# Skipped 2 lines with height less than 25 pixels for ilovepdf_merged-2-20_page-0009.
# Finished processing all images.

# %%
import shutil
from google.colab import files

# Define the directory to zip
directory_to_zip = 'segmented_lines_per_image'

# Define the output zip filename
zip_filename = 'segmented_lines_per_image.zip'

# Create the zip archive
shutil.make_archive(directory_to_zip, 'zip', directory_to_zip)

# Download the zip file
files.download(zip_filename)
